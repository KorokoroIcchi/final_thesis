# %%
import pandas as pd
import numpy as np
import chardet

# %%
with open("../final_paper_data/b01-1-1.csv","rb") as f:
    data = f.read()
    result = chardet.detect(data)
result
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
read_file = pd.read_excel (r"../final_paper_data/b01-1-1.xlsx")
read_file.to_csv (r"../final_paper_data/b01-1-1.csv", index = None, header=True)

# %%
dat1 = pd.read_csv('../final_paper_data/b01-1-1.csv',encoding='ascii')
dat1.head(15)
# Out:
#     Unnamed: 0  Jan.  Feb.  Mar.  Apr.   May  June  July  Aug.  Sep.  ...  \
# 0       1970.0  30.3  30.3  30.6  30.9  30.8  30.8  30.8  30.7  31.2  ...
# 1       1971.0  32.2  32.2  32.3  32.7  32.8  32.9  32.9  32.9  33.7  ...
# 2       1972.0  33.5  33.7  34.0  34.4  34.5  34.5  34.5  34.8  35.0  ...
# 3       1973.0  35.7  36.0  36.9  37.6  38.2  38.3  38.6  38.9  40.0  ...
# 4       1974.0  43.6  45.0  45.3  46.4  46.6  46.9  47.8  48.3  49.0  ...
# 5       1975.0  51.2  51.3  51.7  52.6  52.9  52.9  53.1  52.9  54.1  ...
# 6       1976.0  55.7  56.1  56.3  57.6  57.8  57.9  58.3  57.9  59.4  ...
# 7       1977.0  60.9  61.3  61.6  62.6  63.2  63.0  62.8  62.9  63.9  ...
# 8       1978.0  63.7  64.1  64.6  65.3  65.7  65.4  65.6  65.8  66.5  ...
# 9       1979.0  66.0  65.8  66.4  67.2  67.8  67.9  68.5  67.8  68.7  ...
# 10      1980.0  70.3  70.9  71.3  72.6  73.2  73.5  73.6  73.4  74.6  ...
# 11      1981.0  75.5  75.4  75.6  76.2  76.9  77.0  76.8  76.5  77.6  ...
# ...
